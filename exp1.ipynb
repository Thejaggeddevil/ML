# %%
import panda as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import panda as pd
#
# ModuleNotFoundError: No module named 'panda'

# %%
import pandas as pd

# %%
data = pd.read_csv("Exp1.csv")

# %%
print("Training Data:\n")
print(data)

# Separate features and target
concepts = data.iloc[:, :-1].values
target = data.iloc[:, -1].values

# Initialize hypothesis with first positive example
hypothesis = None

for i in range(len(target)):
    if target[i] == "Yes":
        hypothesis = concepts[i].copy()
        break

# Apply Find-S
for i in range(len(concepts)):
    if target[i] == "Yes":
        for j in range(len(hypothesis)):
            if hypothesis[j] != concepts[i][j]:
                hypothesis[j] = '?'

print("\nFinal Hypothesis:")
print(hypothesis)
# Out:
# Training Data:
#
#       Sky AirTemp Humidity    Wind Water Forecast EnjoySport
# 0   Sunny    Warm   Normal  Strong  Warm     Same        Yes
# 1   Sunny    Warm     High  Strong  Warm     Same        Yes
# 2   Sunny    Warm     High  Strong  Cool   Change        Yes
# 3   Sunny    Warm   Normal    Weak  Warm     Same        Yes
# 4   Sunny    Warm   Normal  Strong  Cool     Same        Yes
# ..    ...     ...      ...     ...   ...      ...        ...
# 75  Sunny    Warm     High  Strong  Cool   Change        Yes
# 76  Sunny    Warm   Normal    Weak  Cool   Change        Yes
# 77  Sunny    Warm     High    Weak  Cool   Change        Yes
# 78  Sunny    Warm   Normal  Strong  Warm   Change        Yes
# 79  Sunny    Warm     High  Strong  Warm   Change        Yes
#
# [80 rows x 7 columns]
#
# Final Hypothesis:
# ['Sunny' 'Warm' '?' '?' '?' '?']
